# %%
import os
import numpy as np
import pandas as pd
import h5py
from pathlib import Path
from scipy.sparse import csr_matrix, csc_matrix
from settings import DATA_DIR

# %%
data_dir = Path(DATA_DIR)
gene_csv_name = 'gene.csv'
non_gene_csv_name = 'non_gene.csv'
non_gene_table_columns = ['tissue_type', 'cell_type', 'size', 'disease', 'sex', 'ethnicity', 'development_stage','assay', 'cell_type_ontology_id', 'dataset']
gene_table_columns = [*non_gene_table_columns[:2], 'gene_ids', *non_gene_table_columns[2:]]

# %% [markdown]
# Structure of the CSV.
#
# - Dataset Name
# - Dataset ID
# - Organ
# - AS UBERON IDs
# - Num Cells
# - Sex
# - Age
# - Donor ID
# - RUI ID

# %%
def read_dataset(dataset_name):
    f = h5py.File(dataset_name, "r")
    title = f['uns']['title'][()].decode('utf-8')
    print(f"Reading {dataset_name} ", title)

    tissue_dict = pd.Series(f['obs']['__categories/tissue']).str.decode('utf-8')
    cell_dict = pd.Series(f['obs']['__categories/cell_type']).str.decode('utf-8')
    # TODO: add blank gene_id values rather than skipping the file
    if '_index' not in f['var']:
        print(f"No gene _index in {dataset_name}")
        return
    if not os.path.exists('data'):
        os.mkdir('data')
    if not os.path.exists('data/gene'):
        os.mkdir('data/gene')
    if not os.path.exists('data/non_gene'):
        os.mkdir('data/non_gene')
    gene_dict = pd.Series(f['var']['_index']).str.decode('utf-8')
    disease_dict = pd.Series(f['obs']['__categories/disease']).str.decode('utf-8')
    assay_dict = pd.Series(f['obs']['__categories/assay']).str.decode('utf-8')
    cell_id_dict = pd.Series(f['obs']['__categories/cell_type_ontology_term_id']).str.decode('utf-8')
    # TODO: add sex/ethnicity/development_stage/disease data too
    sex_types = pd.Series(f['obs']['__categories/sex']).str.decode('utf-8')[f['obs']['sex']] if ('sex' in pd.Series(f['obs']['__categories'])) else pd.Series(['data_unavailable'] * len(f['obs']['sex']))
    #disease_types = pd.Series(f['obs']['__categories/disease']).str.decode('utf-8')[f['obs']['disease']] if ('disease' in pd.Series(f['obs']['__categories'])) else pd.Series(['data_unavailable'] * len(f['obs']['disease']))
    stage_types = pd.Series(f['obs']['__categories/development_stage']).str.decode('utf-8')[f['obs']['development_stage']] if ('development_stage' in pd.Series(f['obs']['__categories'])) else pd.Series(['data_unavailable'] * len(f['obs']['development_stage']))
    ethnicity_types = pd.Series(f['obs']['__categories/ethnicity']).str.decode('utf-8')[f['obs']['ethnicity']] if ('ethnicity' in pd.Series(f['obs']['__categories'])) else pd.Series(['data_unavailable'] * len(f['obs']['ethnicity']))

    tissue_types = tissue_dict[f['obs']['tissue']]
    cell_types = cell_dict[f['obs']['cell_type']]
    cell_type_ids = cell_id_dict[f['obs']['cell_type_ontology_term_id']]
    diseases = disease_dict[f['obs']['disease']]

    attrs = dict(f['X'].attrs)
    if 'encoding-type' in attrs and attrs['encoding-type'] == 'csc_matrix':
        data, indices, indptr = f['X']['data'], f['X']['indices'], f['X']['indptr']
        data = csc_matrix((data, indices, indptr), shape=attrs['shape']).toarray()
    elif 'encoding-type' in attrs and attrs['encoding-type'] == 'csr_matrix':
        data, indices, indptr = f['X']['data'], f['X']['indices'], f['X']['indptr']
        data = csr_matrix((data, indices, indptr), shape=attrs['shape']).toarray()
    else:
        data = np.array(f['X'])

    x, y = data.nonzero()
    gene_ids = []
    for i in range(max(x) + 1):
        start = np.searchsorted(x, i, side='left')
        end = np.searchsorted(x, i, side='right')
        cell_gene_ids = ';'.join(gene_dict[y[start: end]])
        gene_ids.append(cell_gene_ids)

    new_data = pd.DataFrame({
        'tissue_type': tissue_types.values,
        'cell_type': cell_types.values,
        'cell_type_ontology_id': cell_type_ids.values,
        'gene_id': gene_ids,
        'disease': diseases.values,
        'sex' : sex_types.values,
        'ethnicity' : ethnicity_types.values,
        'development_stage' : stage_types.values
    })
    

    new_data = new_data.loc[new_data.disease == 'normal', :]
    #print('Data : \n', new_data)
    gene_group = new_data.groupby(['tissue_type', 'cell_type', 'cell_type_ontology_id'])
    #print('GG \n', gene_group)
    # gene_group = new_data.groupby(['tissue', 'cell_type', 'cell_type_ontology_id'])
    #stage_group = new_data.groupby(['tissue_type', 'cell_type', 'cell_type_ontology_id'])['development_stage']
    #ethnicity_group = new_data.groupby(['tissue_type', 'cell_type', 'cell_type_ontology_id'])['ethnicity']
    #sex_group = new_data.groupby(['tissue_type', 'cell_type', 'cell_type_ontology_id'])['sex']

    #print('Count info : \n', gene_group.count())
    def merge_field_values(x):
        gene_id_set = set()
        for cell_gene_ids in x:
            gene_id_set.update(cell_gene_ids.split(';'))
        if '' in gene_id_set:
            gene_id_set.remove('')
        return ';'.join(gene_id_set)
    
    genes = gene_group.agg(merge_field_values)
    genes['count'] = gene_group.count()['gene_id']
    print('genes : \n', genes)
    genes.to_csv('data/gene/organ_' + str(title).replace(' ', '_') + '.csv')
    non_genes = genes.drop(['gene_id'], axis=1)
    print('Non - genes : \n', non_genes)

    non_genes.to_csv('data/non_gene/organ_' + str(title).replace(' ', '_') + '.csv')

# %%
if __name__ == '__main__':
    with open(gene_csv_name, 'w') as gene_out:
        gene_out.write('|'.join(gene_table_columns) + "\n")
    with open(non_gene_csv_name, 'w') as non_gene_out:
        non_gene_out.write('|'.join(non_gene_table_columns) + "\n")
    with open(non_gene_csv_name, 'w') as non_gene_out:
        non_gene_out.write('|'.join(non_gene_table_columns) + "\n")

    for dataset_name in data_dir.glob('*.h5ad'):
    #for dataset_name in [str(data_dir)+'/c42c8ad3-9761-49e5-b9bf-ee8ebd50416f.h5ad', str(data_dir)+'/f75f2ff4-2884-4c2d-b375-70de37a34507.h5ad']:
        try:
            read_dataset(str(dataset_name))
        except Exception as e:
            print(f"{dataset_name} => {str(e)}")
        break

# %%
import pandas as pd

pd.set_option('max_rows', 20)
pd.set_option('max_columns', None)

# %%
import scanpy as sc

ls = [ds for ds in data_dir.glob('*.h5ad')]
#print(ls)

# %%
len(ls)
# Out:
# 107

# %%
data =  sc.read_h5ad(str(ls[4]), )

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 13782 × 22231
#     obs: 'assay_ontology_term_id', 'development_stage_ontology_term_id', 'donor_BMI', 'donor_uuid', 'ethnicity_ontology_term_id', 'library_uuid', 'mapped_reference_annotation', 'organism_ontology_term_id', 'sample_preservation_method', 'sample_uuid', 'tissue_ontology_term_id', 'tissue_section_thickness', 'tissue_section_uuid', 'is_primary_data', 'author_predicted_cell_type', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'reported_diseases', 'sex_ontology_term_id', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'ethnicity', 'development_stage'
#     var: 'feature_biotype', 'feature_is_filtered', 'feature_name', 'feature_reference'
#     uns: 'X_normalization', 'cell_type_ontology_term_id_colors', 'default_embedding', 'layer_descriptions', 'schema_version', 'title'
#     obsm: 'X_spatial', 'X_umap'

# %%
data.obs
# Out:
#                assay_ontology_term_id development_stage_ontology_term_id  \
# AAAAAAAAAAGTAA            EFO:0009920                     HsapDv:0000169
# AAAAAAAATCATAA            EFO:0009920                     HsapDv:0000169
# AAAAAAACAAAGAC            EFO:0009920                     HsapDv:0000169
# AAAAAAACAATCAC            EFO:0009920                     HsapDv:0000169
# AAAAAAACCAAGAC            EFO:0009920                     HsapDv:0000169
# ...                               ...                                ...
# TTTTTTTTCTGTTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTGTTCTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTATCTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTTATTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTTTTTT            EFO:0009920                     HsapDv:0000169
#
#                donor_BMI                            donor_uuid  \
# AAAAAAAAAAGTAA      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAAATCATAA      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACAAAGAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACAATCAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACCAAGAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# ...                  ...                                   ...
# TTTTTTTTCTGTTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTGTTCTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTATCTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTTATTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTTTTTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
#
#                ethnicity_ontology_term_id  \
# AAAAAAAAAAGTAA             HANCESTRO:0005
# AAAAAAAATCATAA             HANCESTRO:0005
# AAAAAAACAAAGAC             HANCESTRO:0005
# AAAAAAACAATCAC             HANCESTRO:0005
# AAAAAAACCAAGAC             HANCESTRO:0005
# ...                                   ...
# TTTTTTTTCTGTTT             HANCESTRO:0005
# TTTTTTTTGTTCTT             HANCESTRO:0005
# TTTTTTTTTATCTT             HANCESTRO:0005
# TTTTTTTTTTATTT             HANCESTRO:0005
# TTTTTTTTTTTTTT             HANCESTRO:0005
#
#                                         library_uuid  \
# AAAAAAAAAAGTAA  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAAATCATAA  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACAAAGAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACAATCAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACCAAGAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# ...                                              ...
# TTTTTTTTCTGTTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTGTTCTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTATCTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTTATTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTTTTTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
#
#                mapped_reference_annotation organism_ontology_term_id  \
# AAAAAAAAAAGTAA                  GENCODE 19            NCBITaxon:9606
# AAAAAAAATCATAA                  GENCODE 19            NCBITaxon:9606
# AAAAAAACAAAGAC                  GENCODE 19            NCBITaxon:9606
# AAAAAAACAATCAC                  GENCODE 19            NCBITaxon:9606
# AAAAAAACCAAGAC                  GENCODE 19            NCBITaxon:9606
# ...                                    ...                       ...
# TTTTTTTTCTGTTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTGTTCTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTATCTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTTATTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTTTTTT                  GENCODE 19            NCBITaxon:9606
#
#                sample_preservation_method  \
# AAAAAAAAAAGTAA             flash-freezing
# AAAAAAAATCATAA             flash-freezing
# AAAAAAACAAAGAC             flash-freezing
# AAAAAAACAATCAC             flash-freezing
# AAAAAAACCAAGAC             flash-freezing
# ...                                   ...
# TTTTTTTTCTGTTT             flash-freezing
# TTTTTTTTGTTCTT             flash-freezing
# TTTTTTTTTATCTT             flash-freezing
# TTTTTTTTTTATTT             flash-freezing
# TTTTTTTTTTTTTT             flash-freezing
#
#                                          sample_uuid  ...  \
# AAAAAAAAAAGTAA  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# AAAAAAAATCATAA  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# AAAAAAACAAAGAC  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# AAAAAAACAATCAC  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# AAAAAAACCAAGAC  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# ...                                              ...  ...
# TTTTTTTTCTGTTT  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# TTTTTTTTGTTCTT  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# TTTTTTTTTATCTT  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# TTTTTTTTTTATTT  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
# TTTTTTTTTTTTTT  2dab56f7-555c-4737-a25f-54eb30d21f8f  ...
#
#                                                 reported_diseases  \
# AAAAAAAAAAGTAA  [hypertensive disorder,clear cell renal carcin...
# AAAAAAAATCATAA  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACAAAGAC  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACAATCAC  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACCAAGAC  [hypertensive disorder,clear cell renal carcin...
# ...                                                           ...
# TTTTTTTTCTGTTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTGTTCTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTATCTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTTATTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTTTTTT  [hypertensive disorder,clear cell renal carcin...
#
#                sex_ontology_term_id  \
# AAAAAAAAAAGTAA         PATO:0000384
# AAAAAAAATCATAA         PATO:0000384
# AAAAAAACAAAGAC         PATO:0000384
# AAAAAAACAATCAC         PATO:0000384
# AAAAAAACCAAGAC         PATO:0000384
# ...                             ...
# TTTTTTTTCTGTTT         PATO:0000384
# TTTTTTTTGTTCTT         PATO:0000384
# TTTTTTTTTATCTT         PATO:0000384
# TTTTTTTTTTATTT         PATO:0000384
# TTTTTTTTTTTTTT         PATO:0000384
#
#                                                         cell_type      assay  \
# AAAAAAAAAAGTAA  kidney proximal convoluted tubule epithelial cell  Slide-seq
# AAAAAAAATCATAA           kidney collecting duct intercalated cell  Slide-seq
# AAAAAAACAAAGAC                                   endothelial cell  Slide-seq
# AAAAAAACAATCAC                glomerular visceral epithelial cell  Slide-seq
# AAAAAAACCAAGAC                    blood vessel smooth muscle cell  Slide-seq
# ...                                                           ...        ...
# TTTTTTTTCTGTTT           kidney collecting duct intercalated cell  Slide-seq
# TTTTTTTTGTTCTT                                          leukocyte  Slide-seq
# TTTTTTTTTATCTT                                   endothelial cell  Slide-seq
# TTTTTTTTTTATTT                                   endothelial cell  Slide-seq
# TTTTTTTTTTTTTT                                   endothelial cell  Slide-seq
#
#                disease      organism   sex         tissue ethnicity  \
# AAAAAAAAAAGTAA  normal  Homo sapiens  male  renal medulla  European
# AAAAAAAATCATAA  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACAAAGAC  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACAATCAC  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACCAAGAC  normal  Homo sapiens  male  renal medulla  European
# ...                ...           ...   ...            ...       ...
# TTTTTTTTCTGTTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTGTTCTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTATCTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTTATTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTTTTTT  normal  Homo sapiens  male  renal medulla  European
#
#                       development_stage
# AAAAAAAAAAGTAA  75-year-old human stage
# AAAAAAAATCATAA  75-year-old human stage
# AAAAAAACAAAGAC  75-year-old human stage
# AAAAAAACAATCAC  75-year-old human stage
# AAAAAAACCAAGAC  75-year-old human stage
# ...                                 ...
# TTTTTTTTCTGTTT  75-year-old human stage
# TTTTTTTTGTTCTT  75-year-old human stage
# TTTTTTTTTATCTT  75-year-old human stage
# TTTTTTTTTTATTT  75-year-old human stage
# TTTTTTTTTTTTTT  75-year-old human stage
#
# [13782 rows x 27 columns]

# %%
data.var
# Out:
#                 feature_biotype  feature_is_filtered  \
# ENSG00000121410            gene                 True
# ENSG00000268895            gene                False
# ENSG00000148584            gene                 True
# ENSG00000175899            gene                False
# ENSG00000245105            gene                False
# ...                         ...                  ...
# ENSG00000036549            gene                False
# ENSG00000141854            gene                False
# ENSG00000234352            gene                False
# ENSG00000215769            gene                False
# ENSG00000256092            gene                False
#
#                               feature_name feature_reference
# ENSG00000121410                       A1BG    NCBITaxon:9606
# ENSG00000268895                   A1BG-AS1    NCBITaxon:9606
# ENSG00000148584                       A1CF    NCBITaxon:9606
# ENSG00000175899                        A2M    NCBITaxon:9606
# ENSG00000245105                    A2M-AS1    NCBITaxon:9606
# ...                                    ...               ...
# ENSG00000036549                       ZZZ3    NCBITaxon:9606
# ENSG00000141854                      MISP3    NCBITaxon:9606
# ENSG00000234352                 AC009264.1    NCBITaxon:9606
# ENSG00000215769  ARHGAP27P1-BPTFP1-KPNA2P3    NCBITaxon:9606
# ENSG00000256092                  SBNO1-AS1    NCBITaxon:9606
#
# [22231 rows x 4 columns]

# %%
raw_data = data.obs

# %%
pd.set_option('max_rows', 20)
pd.set_option('max_columns', None)
raw_data
# Out:
#                assay_ontology_term_id development_stage_ontology_term_id  \
# AAAAAAAAAAGTAA            EFO:0009920                     HsapDv:0000169
# AAAAAAAATCATAA            EFO:0009920                     HsapDv:0000169
# AAAAAAACAAAGAC            EFO:0009920                     HsapDv:0000169
# AAAAAAACAATCAC            EFO:0009920                     HsapDv:0000169
# AAAAAAACCAAGAC            EFO:0009920                     HsapDv:0000169
# ...                               ...                                ...
# TTTTTTTTCTGTTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTGTTCTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTATCTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTTATTT            EFO:0009920                     HsapDv:0000169
# TTTTTTTTTTTTTT            EFO:0009920                     HsapDv:0000169
#
#                donor_BMI                            donor_uuid  \
# AAAAAAAAAAGTAA      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAAATCATAA      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACAAAGAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACAATCAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# AAAAAAACCAAGAC      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# ...                  ...                                   ...
# TTTTTTTTCTGTTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTGTTCTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTATCTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTTATTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
# TTTTTTTTTTTTTT      28.0  6caaa3d2-bed4-4253-bd57-dca17e93598e
#
#                ethnicity_ontology_term_id  \
# AAAAAAAAAAGTAA             HANCESTRO:0005
# AAAAAAAATCATAA             HANCESTRO:0005
# AAAAAAACAAAGAC             HANCESTRO:0005
# AAAAAAACAATCAC             HANCESTRO:0005
# AAAAAAACCAAGAC             HANCESTRO:0005
# ...                                   ...
# TTTTTTTTCTGTTT             HANCESTRO:0005
# TTTTTTTTGTTCTT             HANCESTRO:0005
# TTTTTTTTTATCTT             HANCESTRO:0005
# TTTTTTTTTTATTT             HANCESTRO:0005
# TTTTTTTTTTTTTT             HANCESTRO:0005
#
#                                         library_uuid  \
# AAAAAAAAAAGTAA  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAAATCATAA  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACAAAGAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACAATCAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# AAAAAAACCAAGAC  cf23c778-0665-4cd5-ba35-d14302fbf16b
# ...                                              ...
# TTTTTTTTCTGTTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTGTTCTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTATCTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTTATTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
# TTTTTTTTTTTTTT  cf23c778-0665-4cd5-ba35-d14302fbf16b
#
#                mapped_reference_annotation organism_ontology_term_id  \
# AAAAAAAAAAGTAA                  GENCODE 19            NCBITaxon:9606
# AAAAAAAATCATAA                  GENCODE 19            NCBITaxon:9606
# AAAAAAACAAAGAC                  GENCODE 19            NCBITaxon:9606
# AAAAAAACAATCAC                  GENCODE 19            NCBITaxon:9606
# AAAAAAACCAAGAC                  GENCODE 19            NCBITaxon:9606
# ...                                    ...                       ...
# TTTTTTTTCTGTTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTGTTCTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTATCTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTTATTT                  GENCODE 19            NCBITaxon:9606
# TTTTTTTTTTTTTT                  GENCODE 19            NCBITaxon:9606
#
#                sample_preservation_method  \
# AAAAAAAAAAGTAA             flash-freezing
# AAAAAAAATCATAA             flash-freezing
# AAAAAAACAAAGAC             flash-freezing
# AAAAAAACAATCAC             flash-freezing
# AAAAAAACCAAGAC             flash-freezing
# ...                                   ...
# TTTTTTTTCTGTTT             flash-freezing
# TTTTTTTTGTTCTT             flash-freezing
# TTTTTTTTTATCTT             flash-freezing
# TTTTTTTTTTATTT             flash-freezing
# TTTTTTTTTTTTTT             flash-freezing
#
#                                          sample_uuid tissue_ontology_term_id  \
# AAAAAAAAAAGTAA  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# AAAAAAAATCATAA  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# AAAAAAACAAAGAC  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# AAAAAAACAATCAC  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# AAAAAAACCAAGAC  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# ...                                              ...                     ...
# TTTTTTTTCTGTTT  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# TTTTTTTTGTTCTT  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# TTTTTTTTTATCTT  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# TTTTTTTTTTATTT  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
# TTTTTTTTTTTTTT  2dab56f7-555c-4737-a25f-54eb30d21f8f          UBERON:0000362
#
#                tissue_section_thickness                   tissue_section_uuid  \
# AAAAAAAAAAGTAA                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# AAAAAAAATCATAA                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# AAAAAAACAAAGAC                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# AAAAAAACAATCAC                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# AAAAAAACCAAGAC                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# ...                                 ...                                   ...
# TTTTTTTTCTGTTT                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# TTTTTTTTGTTCTT                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# TTTTTTTTTATCTT                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# TTTTTTTTTTATTT                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
# TTTTTTTTTTTTTT                     10μm  7df8890e-3960-41d9-bb18-d5cbf6b4c05e
#
#                 is_primary_data author_predicted_cell_type  \
# AAAAAAAAAAGTAA             True                        PCT
# AAAAAAAATCATAA             True                    CD-B-IC
# AAAAAAACAAAGAC             True                Endothelial
# AAAAAAACAATCAC             True                   Podocyte
# AAAAAAACCAAGAC             True                       vSMC
# ...                         ...                        ...
# TTTTTTTTCTGTTT             True                    CD-B-IC
# TTTTTTTTGTTCTT             True                     Immune
# TTTTTTTTTATCTT             True                Endothelial
# TTTTTTTTTTATTT             True                Endothelial
# TTTTTTTTTTTTTT             True                Endothelial
#
#                cell_type_ontology_term_id disease_ontology_term_id  \
# AAAAAAAAAAGTAA                 CL:1000838             PATO:0000461
# AAAAAAAATCATAA                 CL:1001432             PATO:0000461
# AAAAAAACAAAGAC                 CL:0000115             PATO:0000461
# AAAAAAACAATCAC                 CL:0000653             PATO:0000461
# AAAAAAACCAAGAC                 CL:0019018             PATO:0000461
# ...                                   ...                      ...
# TTTTTTTTCTGTTT                 CL:1001432             PATO:0000461
# TTTTTTTTGTTCTT                 CL:0000738             PATO:0000461
# TTTTTTTTTATCTT                 CL:0000115             PATO:0000461
# TTTTTTTTTTATTT                 CL:0000115             PATO:0000461
# TTTTTTTTTTTTTT                 CL:0000115             PATO:0000461
#
#                                                 reported_diseases  \
# AAAAAAAAAAGTAA  [hypertensive disorder,clear cell renal carcin...
# AAAAAAAATCATAA  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACAAAGAC  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACAATCAC  [hypertensive disorder,clear cell renal carcin...
# AAAAAAACCAAGAC  [hypertensive disorder,clear cell renal carcin...
# ...                                                           ...
# TTTTTTTTCTGTTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTGTTCTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTATCTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTTATTT  [hypertensive disorder,clear cell renal carcin...
# TTTTTTTTTTTTTT  [hypertensive disorder,clear cell renal carcin...
#
#                sex_ontology_term_id  \
# AAAAAAAAAAGTAA         PATO:0000384
# AAAAAAAATCATAA         PATO:0000384
# AAAAAAACAAAGAC         PATO:0000384
# AAAAAAACAATCAC         PATO:0000384
# AAAAAAACCAAGAC         PATO:0000384
# ...                             ...
# TTTTTTTTCTGTTT         PATO:0000384
# TTTTTTTTGTTCTT         PATO:0000384
# TTTTTTTTTATCTT         PATO:0000384
# TTTTTTTTTTATTT         PATO:0000384
# TTTTTTTTTTTTTT         PATO:0000384
#
#                                                         cell_type      assay  \
# AAAAAAAAAAGTAA  kidney proximal convoluted tubule epithelial cell  Slide-seq
# AAAAAAAATCATAA           kidney collecting duct intercalated cell  Slide-seq
# AAAAAAACAAAGAC                                   endothelial cell  Slide-seq
# AAAAAAACAATCAC                glomerular visceral epithelial cell  Slide-seq
# AAAAAAACCAAGAC                    blood vessel smooth muscle cell  Slide-seq
# ...                                                           ...        ...
# TTTTTTTTCTGTTT           kidney collecting duct intercalated cell  Slide-seq
# TTTTTTTTGTTCTT                                          leukocyte  Slide-seq
# TTTTTTTTTATCTT                                   endothelial cell  Slide-seq
# TTTTTTTTTTATTT                                   endothelial cell  Slide-seq
# TTTTTTTTTTTTTT                                   endothelial cell  Slide-seq
#
#                disease      organism   sex         tissue ethnicity  \
# AAAAAAAAAAGTAA  normal  Homo sapiens  male  renal medulla  European
# AAAAAAAATCATAA  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACAAAGAC  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACAATCAC  normal  Homo sapiens  male  renal medulla  European
# AAAAAAACCAAGAC  normal  Homo sapiens  male  renal medulla  European
# ...                ...           ...   ...            ...       ...
# TTTTTTTTCTGTTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTGTTCTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTATCTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTTATTT  normal  Homo sapiens  male  renal medulla  European
# TTTTTTTTTTTTTT  normal  Homo sapiens  male  renal medulla  European
#
#                       development_stage
# AAAAAAAAAAGTAA  75-year-old human stage
# AAAAAAAATCATAA  75-year-old human stage
# AAAAAAACAAAGAC  75-year-old human stage
# AAAAAAACAATCAC  75-year-old human stage
# AAAAAAACCAAGAC  75-year-old human stage
# ...                                 ...
# TTTTTTTTCTGTTT  75-year-old human stage
# TTTTTTTTGTTCTT  75-year-old human stage
# TTTTTTTTTATCTT  75-year-old human stage
# TTTTTTTTTTATTT  75-year-old human stage
# TTTTTTTTTTTTTT  75-year-old human stage
#
# [13782 rows x 27 columns]

# %%
#print('Regions : \n {}\n'.format(raw_data['region'].unique()))
#print('Age Group : \n {}\n'.format(raw_data['age_group'].unique()))#
print('Disease : \n {}\n'.format(raw_data['disease'].unique()))
print('Ethnicity : \n {}\n'.format(raw_data['ethnicity'].unique()))
print('Cell type : \n {}\n'.format(raw_data['cell_type'].unique()))


len(raw_data.columns)
# Out:
# Disease :
#  ['normal']
# Categories (1, object): ['normal']
#
# Ethnicity :
#  ['African American']
# Categories (1, object): ['African American']
#
# Cell type :
#  ['endothelial cell', 'glomerular visceral epithelial cell', 'kidney collecting duct principal cell', 'kidney proximal convoluted tubule epithelial ..., 'kidney collecting duct intercalated cell', ..., 'blood vessel smooth muscle cell', 'kidney loop of Henle thick ascending limb epi..., 'macrophage', 'macula densa epithelial cell', 'mesangial cell']
# Length: 14
# Categories (14, object): ['blood vessel smooth muscle cell', 'endothelial cell', 'glomerular visceral epithelial cell', 'kidney collecting duct intercalated cell', ..., 'leukocyte', 'macrophage', 'macula densa epithelial cell', 'mesangial cell']
# 28

# %% [markdown]
# Scrublet score : % of repitition  - Single-cell remover of doublets(SCRUBLET)

# %%
### SORTING LOGIC TO FILTER OUT DISEASE CELLS.

# %%
drop_cols = ['NRP', 'cell_source', 'donor', 'percent_mito', 'percent_ribo', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', \
    'Used', 'assay_ontology_term_id', 'assay', 'cell_type_original', 'development_stage_ontology_term_id', 'ethnicity_ontology_term_id', \
    'disease_ontology_term_id', 'n_genes', 'n_counts', 'gender', 'disease']
refined_data = raw_data[['tissue', 'tissue_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'disease', 'sex', 'donor_uuid', 'ethnicity', 'development_stage', 'assay']]

# %%
refined_data
# Out:
#                        tissue tissue_ontology_term_id  \
# AAAAAAAAAAGTAA  renal medulla          UBERON:0000362
# AAAAAAAATCATAA  renal medulla          UBERON:0000362
# AAAAAAACAAAGAC  renal medulla          UBERON:0000362
# AAAAAAACAATCAC  renal medulla          UBERON:0000362
# AAAAAAACCAAGAC  renal medulla          UBERON:0000362
# ...                       ...                     ...
# TTTTTTTTCTGTTT  renal medulla          UBERON:0000362
# TTTTTTTTGTTCTT  renal medulla          UBERON:0000362
# TTTTTTTTTATCTT  renal medulla          UBERON:0000362
# TTTTTTTTTTATTT  renal medulla          UBERON:0000362
# TTTTTTTTTTTTTT  renal medulla          UBERON:0000362
#
#                                                         cell_type  \
# AAAAAAAAAAGTAA  kidney proximal convoluted tubule epithelial cell
# AAAAAAAATCATAA           kidney collecting duct intercalated cell
# AAAAAAACAAAGAC                                   endothelial cell
# AAAAAAACAATCAC                glomerular visceral epithelial cell
# AAAAAAACCAAGAC                    blood vessel smooth muscle cell
# ...                                                           ...
# TTTTTTTTCTGTTT           kidney collecting duct intercalated cell
# TTTTTTTTGTTCTT                                          leukocyte
# TTTTTTTTTATCTT                                   endothelial cell
# TTTTTTTTTTATTT                                   endothelial cell
# TTTTTTTTTTTTTT                                   endothelial cell
#
#                cell_type_ontology_term_id disease   sex  \
# AAAAAAAAAAGTAA                 CL:1000838  normal  male
# AAAAAAAATCATAA                 CL:1001432  normal  male
# AAAAAAACAAAGAC                 CL:0000115  normal  male
# AAAAAAACAATCAC                 CL:0000653  normal  male
# AAAAAAACCAAGAC                 CL:0019018  normal  male
# ...                                   ...     ...   ...
# TTTTTTTTCTGTTT                 CL:1001432  normal  male
# TTTTTTTTGTTCTT                 CL:0000738  normal  male
# TTTTTTTTTATCTT                 CL:0000115  normal  male
# TTTTTTTTTTATTT                 CL:0000115  normal  male
# TTTTTTTTTTTTTT                 CL:0000115  normal  male
#
#                                           donor_uuid ethnicity  \
# AAAAAAAAAAGTAA  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# AAAAAAAATCATAA  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# AAAAAAACAAAGAC  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# AAAAAAACAATCAC  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# AAAAAAACCAAGAC  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# ...                                              ...       ...
# TTTTTTTTCTGTTT  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# TTTTTTTTGTTCTT  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# TTTTTTTTTATCTT  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# TTTTTTTTTTATTT  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# TTTTTTTTTTTTTT  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
#
#                       development_stage      assay
# AAAAAAAAAAGTAA  75-year-old human stage  Slide-seq
# AAAAAAAATCATAA  75-year-old human stage  Slide-seq
# AAAAAAACAAAGAC  75-year-old human stage  Slide-seq
# AAAAAAACAATCAC  75-year-old human stage  Slide-seq
# AAAAAAACCAAGAC  75-year-old human stage  Slide-seq
# ...                                 ...        ...
# TTTTTTTTCTGTTT  75-year-old human stage  Slide-seq
# TTTTTTTTGTTCTT  75-year-old human stage  Slide-seq
# TTTTTTTTTATCTT  75-year-old human stage  Slide-seq
# TTTTTTTTTTATTT  75-year-old human stage  Slide-seq
# TTTTTTTTTTTTTT  75-year-old human stage  Slide-seq
#
# [13782 rows x 10 columns]

# %%
refined_data = refined_data.reset_index()
refined_data['tissues'] = refined_data['tissue'].astype(str) +  '|' +  refined_data['tissue_ontology_term_id'].astype(str) 
refined_data = refined_data.drop(['index', 'tissue', 'tissue_ontology_term_id'], axis=1)
refined_data
# Out:
#                                                cell_type  \
# 0      kidney proximal convoluted tubule epithelial cell
# 1               kidney collecting duct intercalated cell
# 2                                       endothelial cell
# 3                    glomerular visceral epithelial cell
# 4                        blood vessel smooth muscle cell
# ...                                                  ...
# 13777           kidney collecting duct intercalated cell
# 13778                                          leukocyte
# 13779                                   endothelial cell
# 13780                                   endothelial cell
# 13781                                   endothelial cell
#
#       cell_type_ontology_term_id disease   sex  \
# 0                     CL:1000838  normal  male
# 1                     CL:1001432  normal  male
# 2                     CL:0000115  normal  male
# 3                     CL:0000653  normal  male
# 4                     CL:0019018  normal  male
# ...                          ...     ...   ...
# 13777                 CL:1001432  normal  male
# 13778                 CL:0000738  normal  male
# 13779                 CL:0000115  normal  male
# 13780                 CL:0000115  normal  male
# 13781                 CL:0000115  normal  male
#
#                                  donor_uuid ethnicity  \
# 0      6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 1      6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 2      6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 3      6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 4      6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# ...                                     ...       ...
# 13777  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 13778  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 13779  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 13780  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
# 13781  6caaa3d2-bed4-4253-bd57-dca17e93598e  European
#
#              development_stage      assay                       tissues
# 0      75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 1      75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 2      75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 3      75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 4      75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# ...                        ...        ...                           ...
# 13777  75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 13778  75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 13779  75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 13780  75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
# 13781  75-year-old human stage  Slide-seq  renal medulla|UBERON:0000362
#
# [13782 rows x 9 columns]

# %%
pd.set_option('max_rows', 80)
pd.set_option('max_columns', None)

# %%
refined_data.groupby([ 
'sex', 
'age_group', 
'development_stage',
'tissues',
#'tissue',
#'tissue_ontology_term_id',
'cell_type_ontology_term_id',
'cell_type',
]).count().head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-2fe79a75a7aa> in <module>
# ----> 1 refined_data.groupby([
#       2 'sex',
#       3 'age_group',
#       4 'development_stage',
#       5 'tissues',
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7625         # "Union[bool, NoDefault]"; expected "bool"
# -> 7626         return DataFrameGroupBy(
#    7627             obj=self,
#    7628             keys=by,
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     886             from pandas.core.groupby.grouper import get_grouper
#     887
# --> 888             grouper, exclusions, obj = get_grouper(
#     889                 obj,
#     890                 keys,
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     858                 in_axis, level, gpr = False, gpr, None
#     859             else:
# --> 860                 raise KeyError(gpr)
#     861         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     862             # Add key to exclusions
#
# KeyError: 'age_group'

# %%
refined_data.groupby([ 
'sex', 
'age_group', 
'development_stage',
'tissues',
#'tissue',
#'tissue_ontology_term_id',
'cell_type_ontology_term_id',
'cell_type',
]).agg({'region':['count']}).head(50)
# Out:
#                                                                                                                                 region
#                                                                                                                                  count
# sex    age_group development_stage       tissues                                cell_type_ontology_term_id cell_type
# female 40-45     40-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte     10
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte     22
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte     81
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      7
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte    298
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte     34
#                  45-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  50-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  55-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  60-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  65-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  70-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#        45-50     40-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte      0
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      0
#                                          heart right ventricle|UBERON:0002080   CL:1000309                 epicardial adipocyte      0
#                                          interventricular septum|UBERON:0002094 CL:1000309                 epicardial adipocyte      0
#                                          left cardiac atrium|UBERON:0002079     CL:1000309                 epicardial adipocyte      0
#                                          right cardiac atrium|UBERON:0002078    CL:1000309                 epicardial adipocyte      0
#                  45-year-old human stage apex of heart|UBERON:0002098           CL:1000309                 epicardial adipocyte    111
#                                          heart left ventricle|UBERON:0002084    CL:1000309                 epicardial adipocyte      5

# %%
ds = refined_data[['cell_type', 'n_counts']]

# %%
ds
# Out:
#                  cell_type  n_counts
# 0     epicardial adipocyte    6881.0
# 1     epicardial adipocyte    5889.0
# 2     epicardial adipocyte    2143.0
# 3     epicardial adipocyte    5080.0
# 4     epicardial adipocyte   12483.0
# ...                    ...       ...
# 3794  epicardial adipocyte    3669.0
# 3795  epicardial adipocyte    2858.0
# 3796  epicardial adipocyte    2672.0
# 3797  epicardial adipocyte    1910.0
# 3798  epicardial adipocyte    4566.0
#
# [3799 rows x 2 columns]
